# %% [markdown]
# # Baseline Modeling - Naive Bayes & Logistic Regression

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.functions import col, split

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import json

import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('wordnet')


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


import re

from langdetect import detect

import pickle
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sineadoconnor/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %%
fastFoodDF = spark.read.json('../SavedFiles/fastFood.json')

# %% [markdown]
# ## Pre-processing the text

# %% [markdown]
# ### Removing Non-English Reviews

# %%
def lang_filter(text):
    """Filter non-english reviews"""
    try:
        if detect(text) == 'en':
            return 'english'
        else:
            return 'other'
    except:
        return '?'

#my computer  cannot run this on full set of reviews this so I will do some other filtering first

# %%
#tokenize the reviews

from pyspark.sql.types import ArrayType
from pyspark.sql.types import StringType
import string

punc = [ch for ch in string.punctuation] 

tok_udf = udf((lambda text: " ".join([w for w in wordpunct_tokenize(text.lower()) if w.isalpha() or w in punc])), 
              StringType())

fastFoodDF = fastFoodDF = fastFoodDF.withColumn('text_tok', tok_udf(fastFoodDF.text))

# %%
sw = stopwords.words('english')
sw = word_tokenize(' '.join([w for w in sw]))
sw = sw + ['.', ',', '...', '\'\'', '\"', '``', '¡',  '{','|','||','}', '(',')']

# %%
fren = set(stopwords.words('french'))
for word in ['on','me','s','t', 'ton', 'son','m','d','n','as']:
    fren.remove(word)
span = set(stopwords.words('spanish'))
for word in ['no','a','he','me','has','son']:
    span.remove(word)
ger = set(stopwords.words('german'))
for word in ['am', 'an', 'in','im','die','dies','also','war', 'hat', 'man', 'so', 'was','will']:
    ger.remove(word)

# %%
fren
# Out:
# {'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'ils',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'mes',
#  'moi',
#  'mon',
#  'même',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'ont',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'sera',
#  'serai',
#  'seraient',
#  'serais',
#  'serait',
#  'seras',
#  'serez',
#  'seriez',
#  'serions',
#  'serons',
#  'seront',
#  'ses',
#  'soient',
#  'sois',
#  'soit',
#  'sommes',
#  'sont',
#  'soyez',
#  'soyons',
#  'suis',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'y',
#  'à',
#  'étaient',
#  'étais',
#  'était',
#  'étant',
#  'étante',
#  'étantes',
#  'étants',
#  'étiez',
#  'étions',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'êtes'}

# %%
span
# Out:
# {'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'ha',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'han',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'hemos',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'la',
#  'las',
#  'le',
#  'les',
#  'lo',
#  'los',
#  'mi',
#  'mis',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'ni',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'o',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'pero',
#  'poco',
#  'por',
#  'porque',
#  'que',
#  'quien',
#  'quienes',
#  'qué',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'sentid',
#  'sentida',
#  'sentidas',
#  'sentido',
#  'sentidos',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'siente',
#  'sin',
#  'sintiendo',
#  'sobre',
#  'sois',
#  'somos',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'también',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'tenemos',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'ti',
#  'tiene',
#  'tienen',
#  'tienes',
#  'todo',
#  'todos',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'un',
#  'una',
#  'uno',
#  'unos',
#  'vosotras',
#  'vosotros',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos'}

# %%
ger
# Out:
# {'aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'das',
#  'dass',
#  'dasselbe',
#  'dazu',
#  'daß',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'dem',
#  'demselben',
#  'den',
#  'denn',
#  'denselben',
#  'der',
#  'derer',
#  'derselbe',
#  'derselben',
#  'des',
#  'desselben',
#  'dessen',
#  'dich',
#  'diese',
#  'dieselbe',
#  'dieselben',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'dir',
#  'doch',
#  'dort',
#  'du',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einiges',
#  'einmal',
#  'er',
#  'es',
#  'etwas',
#  'euch',
#  'euer',
#  'eure',
#  'eurem',
#  'euren',
#  'eurer',
#  'eures',
#  'für',
#  'gegen',
#  'gewesen',
#  'hab',
#  'habe',
#  'haben',
#  'hatte',
#  'hatten',
#  'hier',
#  'hin',
#  'hinter',
#  'ich',
#  'ihm',
#  'ihn',
#  'ihnen',
#  'ihr',
#  'ihre',
#  'ihrem',
#  'ihren',
#  'ihrer',
#  'ihres',
#  'indem',
#  'ins',
#  'ist',
#  'jede',
#  'jedem',
#  'jeden',
#  'jeder',
#  'jedes',
#  'jene',
#  'jenem',
#  'jenen',
#  'jener',
#  'jenes',
#  'jetzt',
#  'kann',
#  'kein',
#  'keine',
#  'keinem',
#  'keinen',
#  'keiner',
#  'keines',
#  'können',
#  'könnte',
#  'machen',
#  'manche',
#  'manchem',
#  'manchen',
#  'mancher',
#  'manches',
#  'mein',
#  'meine',
#  'meinem',
#  'meinen',
#  'meiner',
#  'meines',
#  'mich',
#  'mir',
#  'mit',
#  'muss',
#  'musste',
#  'nach',
#  'nicht',
#  'nichts',
#  'noch',
#  'nun',
#  'nur',
#  'ob',
#  'oder',
#  'ohne',
#  'sehr',
#  'sein',
#  'seine',
#  'seinem',
#  'seinen',
#  'seiner',
#  'seines',
#  'selbst',
#  'sich',
#  'sie',
#  'sind',
#  'solche',
#  'solchem',
#  'solchen',
#  'solcher',
#  'solches',
#  'soll',
#  'sollte',
#  'sondern',
#  'sonst',
#  'um',
#  'und',
#  'uns',
#  'unser',
#  'unsere',
#  'unserem',
#  'unseren',
#  'unseres',
#  'unter',
#  'viel',
#  'vom',
#  'von',
#  'vor',
#  'waren',
#  'warst',
#  'weg',
#  'weil',
#  'weiter',
#  'welche',
#  'welchem',
#  'welchen',
#  'welcher',
#  'welches',
#  'wenn',
#  'werde',
#  'werden',
#  'wie',
#  'wieder',
#  'wir',
#  'wird',
#  'wirst',
#  'wo',
#  'wollen',
#  'wollte',
#  'während',
#  'würde',
#  'würden',
#  'zu',
#  'zum',
#  'zur',
#  'zwar',
#  'zwischen',
#  'über'}

# %%
fren_span_ger = set(list(fren)+list(span)+list(ger))

# %%
#to check for foreign stopwords and non-ascii characters

not_eng_udf = udf((lambda text: [w for w in word_tokenize(text) if w.lower() in fren_span_ger or not w.isascii()]), 
                  ArrayType(StringType()))

tempDF = fastFoodDF.withColumn('not_eng', not_eng_udf(fastFoodDF.text_tok))

# %%
tempDF = tempDF.toPandas()

# %%
tempDF['num_non_eng'] = tempDF.not_eng.apply(lambda x: len(x))

# %%
maybe_eng = tempDF[(tempDF.num_non_eng != 0)]
maybe_eng
# Out:
#                    business_id                  city                 date  \
# 1       aZOoc-87ESqy8apJO3J-Yw               Gilbert  2017-05-28 23:01:26
# 6       OUB81Dpb6m7HjW4ZmeSlmw               Toronto  2016-03-21 18:55:27
# 17      KpG24S0VRTvPqNh_qC-wLg                Peoria  2017-02-14 00:10:26
# 29      dKdApYVFDSNYsNOso6NYlA             Las Vegas  2015-04-19 06:59:59
# 33      dKdApYVFDSNYsNOso6NYlA             Las Vegas  2015-02-06 19:43:18
# 51      19wIOjBlI_2EKGM8E4O6Mg             Las Vegas  2015-07-20 02:03:52
# 52      M7gB_MsmKwjSO8pk1rQ00w               Toronto  2015-12-08 06:11:43
# 58      e8wPL-2r2F6-7ucb_VOilA                  Mesa  2016-07-19 18:54:13
# 59      pSMK_FtULKiU-iuh7SMKwg               Toronto  2016-04-16 22:43:36
# 78      vnYtZv_GA_2Xfi2DefbvCg         Saint-Laurent  2018-07-11 17:36:35
# 85      ePVVYZlBCOyPqK_XYnfJWg             Las Vegas  2018-07-10 20:23:02
# 87      H3EBEKejPL8tsB1gQYG1Ew             Charlotte  2018-03-07 20:23:32
# 91      0h4RFNScYBmtNhXAdz_UBA           Monroeville  2018-09-29 12:56:53
# 93      dKdApYVFDSNYsNOso6NYlA             Las Vegas  2016-01-07 19:45:03
# 103     KRyPa25ky1sD3nCIKBG9TQ               Concord  2012-07-20 19:03:54
# 105     DysXlYb_WVlksoip8atIvQ             Champaign  2016-06-03 04:21:04
# 108     Fho2P7OP80-yChCRxkK7Hw             Las Vegas  2017-07-20 01:17:22
# 115     xciltiK8FS6iurTcWtqiYw               Calgary  2012-12-15 04:34:23
# 117     a7shUJaC5xM_BHODzuCR9Q              Montréal  2018-02-05 02:25:16
# 122     wZkjm9TGa7nXLYHxhIRO5w             Las Vegas  2018-05-02 21:11:14
# 125     ZoCCW3R_LEAzktU0rMbX8w             Las Vegas  2015-04-20 17:38:13
# 131     7_F6dA9xh2lydTtr1LCtIQ             Las Vegas  2016-03-23 15:43:35
# 135     Yq92uUpugGyJLvDtcDRunw             Las Vegas  2012-02-07 16:31:59
# 138     SNWlgY-hTUr6h2kEee6gCA               Toronto  2018-01-13 16:55:09
# 141     H_eO04NZAQIDcbtFQ4BUag             Las Vegas  2011-02-21 00:22:41
# 91      This is probably my favorite "fast food" place...       0         221
# 93      No where like the ones in NYC.  No fish sandwi...       0         255
# 103     Another day...another Five Guys to review! At ...       0          78
# 105     McDonald's isn't a great place to eat and neve...       0         313
# 108     So the last time I went they forgot something ...       0         116
# 115     Close to home, see this place all the time, th...       1         200
# 117     C'est de la nourriture "thai" américanisé diso...       0         111
# 122     I like it very much! Today is my first time co...       0          47
# 125     Food was great like always but the the people ...       1          90
# 131     Why is it so difficult to get an order correct...       8         112
# 135     OMG, these are possibly THE BEST fast food bur...       1          94
# 138     I thought technology was supposed to improve e...       1          81
# 141     This is the kind of Chinese take-out place you...       2          92
# 159     Best burritos in Las Vegas other places way to...       0          16
# 174     I was hoping this place would knock it out of ...       0         169
# 181     In-N-Out Burger - Las Vegas (215 & S. Eastern ...       7         144
# 222     Now this is one fancy treat! I went to this mc...       4          78
# 227     Even though it's a chain not all chain's are b...       3          72
# ...                                                   ...     ...         ...
# 220152  Does not take subway gift cards or subway coup...       1         104
# 220162  My worst experiences at Culver's has happened ...       2         168
# 220164  4.5 stars \n\nThe details of of my first time ...       7         173
# 220170  This place used to be really good. Drove acros...       1         237
# 220183  Not bad, not great. Would I eat here again? Wh...       2         344
# 220189  Went through the drive thru ordered 3 hot n sp...       1         173
# 220192  I has been years since I last had Panda Expres...       4         158
# 220199  You can find cheaper, better sandwiches on the...       0          96
# 220214  One dollar to use a credit card after ordering...       1          37
# 220250  This Popeyes is located in the Northwest area ...       2         238
# 220267  Stopped in on a whim instead of walking by as ...       4         138
# 220279  Overpriced hipster-businessman food. The kimch...       0          68
# 220292  Nicest mc ds I've ever seen! Relaxed, big, pre...       0          63
# 220298  Instead of our usual family meal we opted to t...       0         117
# 220308  I enjoy Del Tacos Turkey Tacos with extra chee...       1          51
# 220315  I come here just for the Cajun fries.  The bur...       0          34
# 220327  I can see why they are 3 stars. The food is de...       0          87
# 220331  The service at this J in the B location makes ...       1         136
# 220346  3 chicken rolled tacos for only $2.25 with no ...       1          70
# 220369  I would rate better but the service is poor at...       4         101
# 220381  I like Del Taco for the most part.  But this l...       1         230
# 220432  I am confident to say that this is one of the ...       5         139
# 220438  This place is always busy. I don't get it.\n\n...       1          49
# 220444  I agree with a lot of the recent reviews, serv...       1          77
# 220456  Just picked up an online order. No protein was...       0          24
# 220457  This is chain pizza place...so you cant compar...       0          99
# 220462  I work downtown and this McDonald's location i...       2         166
# 220470  Wow. So I understand this is a fast food joint...       0          40
# 220479  Here's why I like kiosks to order my food.  I ...       0         228
# 220481  So I went in ordered my sandwich they took for...       0         208
#
#                                                  text_tok  \
# 1       what a welcome concept in fast food . cute pla...
# 6       mostly known for their pork belly bao . they a...
# 17      ハンバーガーといえばこのお店で間違いありません タマネギを入れるか入れないか 入れるタマネギ...
# 29      " it taste so good when it hits the lips this ...
# 33      i see a lot of bad ratings about this place an...
# 51      it ' s been a few years since a review here , ...
# 52      i came here after a long study session and sup...
# 58      las sendas is maybe a minute drive from this l...
# 59      menu : http www . blazepizza . com / menu / wh...
# 78      it ' s been great for a quick lunch menu . bee...
# 85      would not recommend this location . i only com...
# 87      shockingly horrible service for any place , bu...
# 91      this is probably my favorite " fast food " pla...
# 93      no where like the ones in nyc . no fish sandwi...
# 103     another day another five guys to review ! at t...
# 105     mcdonald ' s isn ' t a great place to eat and ...
# 108     so the last time i went they forgot something ...
# 115     close to home , see this place all the time , ...
# 117     c ' est de la nourriture " thai " américanisé ...
# 122     i like it very much ! today is my first time c...
# 125     food was great like always but the the people ...
# 131     why is it so difficult to get an order correct...
# 135     omg , these are possibly the best fast food bu...
# 138     i thought technology was supposed to improve e...
# 141     this is the kind of chinese take - out place y...
# 159     best burritos in las vegas other places way to...
# 174     i was hoping this place would knock it out of ...
# 181     in - n - out burger - las vegas ( & s . easter...
# 222     now this is one fancy treat ! i went to this m...
# 227     even though it ' s a chain not all chain ' s a...
# ...                                                   ...
# 220152  does not take subway gift cards or subway coup...
# 220162  my worst experiences at culver ' s has happene...
# 220164  . stars the details of of my first time trying...
# 220170  this place used to be really good . drove acro...
# 220183  not bad , not great . would i eat here again ?...
# 220189  went through the drive thru ordered hot n spic...
# 220192  i has been years since i last had panda expres...
# 220199  you can find cheaper , better sandwiches on th...
# 220214  one dollar to use a credit card after ordering...
# 220250  this popeyes is located in the northwest area ...
# 220267  stopped in on a whim instead of walking by as ...
# 220279  overpriced hipster - businessman food . the ki...
# 220292  nicest mc ds i ' ve ever seen ! relaxed , big ...
# 220298  instead of our usual family meal we opted to t...
# 220308  i enjoy del tacos turkey tacos with extra chee...
# 220315  i come here just for the cajun fries . the bur...
# 220327  i can see why they are stars . the food is dec...
# 220331  the service at this j in the b location makes ...
# 220346  chicken rolled tacos for only $ . with no guac...
# 220369  i would rate better but the service is poor at...
# 220381  i like del taco for the most part . but this l...
# 220432  i am confident to say that this is one of the ...
# 220438  this place is always busy . i don ' t get it ....
# 220444  i agree with a lot of the recent reviews , ser...
# 220456  just picked up an online order . no protein wa...
# 220457  this is chain pizza place so you cant compare ...
# 220462  i work downtown and this mcdonald ' s location...
# 220470  wow . so i understand this is a fast food join...
# 220479  here ' s why i like kiosks to order my food . ...
# 220481  so i went in ordered my sandwich they took for...
#
#                                                   not_eng  num_non_eng
# 1                                              [jalapeño]            1
# 6                                                    [mi]            1
# 17      [ハンバーガーといえばこのお店で間違いありません, タマネギを入れるか入れないか, 入れるタ...            4
# 29                                                  [las]            1
# 33                                                  [las]            1
# 51                                                  [las]            1
# 52                                                   [al]            1
# 58                                                  [las]            1
# 59                                                   [ne]            1
# 78                                             [jalapeño]            1
# 85                                                   [el]            1
# 87                                                   [um]            1
# 91                                                   [yo]            1
# 93                                              [er, las]            2
# 103                                           [jalapeños]            1
# 105                                                 [par]            1
# 108                                                 [del]            1
# 115                                                 [par]            1
# 117     [c, est, de, la, américanisé, le, végé, ce, qu...           62
# 122                                                   [j]            1
# 125                                                  [un]            1
# 131                                                  [ya]            1
# 135                                                 [las]            1
# 138                                                [l, o]            2
# 141                                                 [las]            1
# 159                                                 [las]            1
# 174                                                  [mi]            1
# 181                                                 [las]            1
# 747     Faut pas bouder son plaisir. Évidemment c'est ...       0          62
# 1007    Rivas mexican grill sin duda alguna lo recomie...       1          40
# 1029    Service très lent. La caisse est toujours ferm...       1          21
# 1095    "Convenablement modeste et convivial avec bonn...       0         306
# 1222    J'adore Harvey's! J'aime bcp leurs hamburgers ...       0          23
# 1397    Da Bologna est véritablement le bijou de Montr...       6          95
# 1555    Au cœur du quartier latin, le Saint-Sulpice, c...       3         208
# 1656    J'y vais habituellement pour le cafe mais cett...       1          68
# 1680    Premièrement, juste le fait qu'on ne peut pas ...       2         166
# 1716    Super bar où passer un bon moment entre amis, ...       2          82
# 1839    Première visite à cet endroit. \nPremièrement ...       3         126
# 1860    Je n'encouragerai pas ce genre d'entreprise qu...       0          94
# 2893    harvey's classique. Le meilleur hamburger des ...       0          14
# 2994    L'endroit où j'ai passé une bonne partie de me...       2          80
# 3181    Café ou pas ? J'ai tellement monter de marche ...       0          85
# 3303    C'est absolument ENORME : plein d'étages, une ...       2         207
# 3495    Muy buena comida, excelente sabor y calidad. L...       0          28
# 3731    Voilà trois fois que je vais prendre le petit ...       1         250
# 3887    Toujours contente de trouver un restaurant ouv...       0          57
# 3920    Pour vrai, les meilleures frites de Montréal!!...       1          53
# 3966    Ah le St Sulpice!\nL'endroit in du centre vill...       2         172
# 4331    J'ai commandé le burger de poulet ''Chubby bos...       0         122
# 4343    La mejor comida mexicana en Phoenix 100% recom...       0          33
# 4590    Je n'ecrit jamais de commentaire sur cette cha...       2          42
# 5227    Excelentes precios!! Y la comida esta muy rica...       0          20
# 5665    Sin duda uno de mis lugares favoritos  ! A mi ...       1          23
# 5909    Pongo un estrella porque no queda de otra si n...       0          36
# ...                                                   ...     ...         ...
# 212251  Wow wow wow. Un petit coup de coeur dans la vi...       3          69
# 212616  I I I I I ii. I I I I I I I loivvvvvreeeeeee m...       1          35
# 212654  C'est un article du journal de Montréal qui m'...       4         354
# 213240  Un de mes meilleurs PFK je fait toujours ben 2...       8          35
# 213623  Ordene Los chilaquiles rojos y me dieron una c...       0          18
# 213844  Décadent! \nBouffe hyper réconfortante! \nPas ...       1          27
# 214327  Les frites sont délicieuses mais le sandwich v...       1          31
# 215331  Il y a longtemps que je voulais l'essayer. J'a...       0         132
# 215353  Desagradable experiencia, compre un burrito de...       0          37
# 215390  Restaurant qui faut y aller ses sur \nY'a des ...       9          86
# 215483  Die kleine Carl's Jr Filiale im Flughafen kann...       0          43
# 215948  好耐无吃subway ,突然想吃。逛完超市就去了隔离间subway买6inch包吃。呢间su...       0          13
# 216127  Magnifique! Me suis fait plaisir hier soir à 2...       1          21
# 216268  Meilleurs déjeuners pour un prix très bas. De ...       1          42
# 216309  Un peu déçu de ce Resto. En premier je trouve ...       3          21
# 216379  每次经过总有一堆人排队，晚上去问左门口排筹个人几点关门，晚上12点。晚上唔晒就排下，比早上排...       1          26
# 216702  Grosse nouvelle!!!!!!\n\nIl y a un nouveau Dil...       4         123
# 216797  Was ist denn jetzt los?\nWo man mir vor drei J...       1         164
# 216886  Degeulasse . Service très lent pour un McDonal...       0          30
# 217074  Vraiment meilleur que le st-hubert de sainte-j...       1          56
# 217075  Le concept est parfait. Un neo fast food qui s...       1          27
# 217365  26 mai 2013\nEnfin, le premier Harvey's du DIX...       0         255
# 217833  El personal, fue muy amable y considerado al p...       0          37
# 217978  Mal organisés, des plats (crèmes glacées) impo...       0          38
# 218066  L'hamburger steak est ok  mais trop chère. Il ...       1          51
# 218095  Muy lujoso comparado con otros, la muy lindo, ...       0          23
# 218821  Fantastique jusqu'à tout récemment! Portions g...       0          41
# 219057  Service a la clientèle très médiocre chaque fo...       0          39
# 219087  haller mande a mi hijo mallor para que fuera a...       0         119
# 219802  Super pizza ! La pâte est vraiment parfaite et...       1          29
#
#                                                  text_tok  \
# 17      ハンバーガーといえばこのお店で間違いありません タマネギを入れるか入れないか 入れるタマネギ...
# 117     c ' est de la nourriture " thai " américanisé ...
# 330     le service à la clientèle est à revoir , car l...
# 747     faut pas bouder son plaisir . évidemment c ' e...
# 1007    rivas mexican grill sin duda alguna lo recomie...
# 1029    service très lent . la caisse est toujours fer...
# 1095    " convenablement modeste et convivial avec bon...
# 1222    j ' adore harvey ' s ! j ' aime bcp leurs hamb...
# 1397    da bologna est véritablement le bijou de montr...
# 1555    au cœur du quartier latin , le saint - sulpice...
# 1656    j ' y vais habituellement pour le cafe mais ce...
# 1680    premièrement , juste le fait qu ' on ne peut p...
# 1716    super bar où passer un bon moment entre amis ,...
# 1839    première visite à cet endroit . premièrement l...
# 1860    je n ' encouragerai pas ce genre d ' entrepris...
# 2893    harvey ' s classique . le meilleur hamburger d...
# 2994    l ' endroit où j ' ai passé une bonne partie d...
# 3181    café ou pas ? j ' ai tellement monter de march...
# 3303    c ' est absolument enorme : plein d ' étages ,...
# 3495    muy buena comida , excelente sabor y calidad ....
# 3731    voilà trois fois que je vais prendre le petit ...
# 3887    toujours contente de trouver un restaurant ouv...
# 3920    pour vrai , les meilleures frites de montréal ...
# 3966    ah le st sulpice ! l ' endroit in du centre vi...
# 4331    j ' ai commandé le burger de poulet chubby bos...
# 4343    la mejor comida mexicana en phoenix % recomend...
# 4590    je n ' ecrit jamais de commentaire sur cette c...
# 5227    excelentes precios y la comida esta muy rica ....
# 5665    sin duda uno de mis lugares favoritos ! a mi f...
# 5909    pongo un estrella porque no queda de otra si n...
# ...                                                   ...
# 212251  wow wow wow . un petit coup de coeur dans la v...
# 212616  i i i i i ii . i i i i i i i loivvvvvreeeeeee ...
# 212654  c ' est un article du journal de montréal qui ...
# 213240  un de mes meilleurs pfk je fait toujours ben m...
# 213623  ordene los chilaquiles rojos y me dieron una c...
# 213844  décadent ! bouffe hyper réconfortante ! pas ch...
# 214327  les frites sont délicieuses mais le sandwich v...
# 215331  il y a longtemps que je voulais l ' essayer . ...
# 215353  desagradable experiencia , compre un burrito d...
# 215390  restaurant qui faut y aller ses sur y ' a des ...
# 215483  die kleine carl ' s jr filiale im flughafen ka...
# 215948  好耐无吃subway , 突然想吃 呢间subway虽然系超市隔离 但不算特别人多 通产都有...
# 216127  magnifique ! me suis fait plaisir hier soir à ...
# 216268  meilleurs déjeuners pour un prix très bas . de...
# 216309  un peu déçu de ce resto . en premier je trouve...
# 216379  每次经过总有一堆人排队 晚上去问左门口排筹个人几点关门 晚上唔晒就排下 比早上排得快 大概半...
# 216702  grosse nouvelle il y a un nouveau dilallo - ak...
# 216797  was ist denn jetzt los ? wo man mir vor drei j...
# 216886  degeulasse . service très lent pour un mcdonal...
# 217074  vraiment meilleur que le st - hubert de sainte...
# 217075  le concept est parfait . un neo fast food qui ...
# 217365  mai enfin , le premier harvey ' s du enfin . u...
# 217833  el personal , fue muy amable y considerado al ...
# 217978  mal organisés , des plats ( crèmes glacées ) i...
# 218066  l ' hamburger steak est ok mais trop chère . i...
# 218095  muy lujoso comparado con otros , la muy lindo ...
# 218821  fantastique jusqu ' à tout récemment ! portion...
# 219057  service a la clientèle très médiocre chaque fo...
# 219087  haller mande a mi hijo mallor para que fuera a...
# 219802  super pizza ! la pâte est vraiment parfaite et...
#
#                                                   not_eng  num_non_eng   lang
# 17      [ハンバーガーといえばこのお店で間違いありません, タマネギを入れるか入れないか, 入れるタ...            4  other
# 117     [c, est, de, la, américanisé, le, végé, ce, qu...           62  other
# 330     [le, à, la, clientèle, est, à, le, est, très, ...           32  other
# 747     [pas, évidemment, c, est, un, mais, c, est, dr...           36  other
# 1007    [sin, lo, de, es, una, hay, algo, este, en, el...           18  other
# 1029    [très, la, est, fermée, au, à, la, clientèle, ...           10  other
# 1095    [et, avec, nous, y, étions, allés, à, de, par,...          184  other
# 1222    [j, j, à, la, clientèle, très, des, qui, y, très]           10  other
# 1397    [da, est, véritablement, le, de, montréal, en,...           59  other
# 1555    [au, cœur, du, le, communément, un, montréalai...          108  other
# 1656    [j, y, pour, le, mais, ce, fut, pour, un, la, ...           33  other
# 1680    [premièrement, le, qu, ne, pas, par, c, est, q...          108  other
# 1716    [où, un, entre, une, ou, pas, énorme, capacité...           31  other
# 1839    [première, à, premièrement, le, est, une, qui,...           71  other
# 1860    [je, pas, ce, qui, une, employée, à, la, pour,...           49  other
# 2893                       [le, des, chaînes, de, à, mon]            6  other
# 2994    [l, où, j, ai, passé, une, de, mes, soirées, g...           50  other
# 3181    [café, ou, pas, j, ai, de, pour, mes, du, québ...           48  other
# 3303    [c, est, étages, une, et, un, été, y, de, la, ...          105  other
# 3495    [muy, y, los, y, de, los, de, y, la, atención,...           14  other
# 3731    [voilà, que, je, le, déjeuner, et, c, est, trè...          141  other
# 3887    [de, un, ça, c, est, l, est, ma, sélection, de...           28  other
# 3920    [pour, les, de, montréal, et, leur, épicée, le...           25  other
# 3966    [le, l, du, de, montréal, j, y, ai, passé, de,...           95  other
# 4331    [j, ai, commandé, le, de, et, c, était, délici...           63  other
# 4343    [la, en, la, de, mis, las, todo, y, el, muy, e...           16  other
# 4590    [je, de, sur, de, je, que, du, mais, la, je, n...           25  other
# 5227         [y, la, esta, muy, la, es, y, las, que, muy]           10  other
# 5665    [sin, uno, de, mis, mi, y, mi, nos, todo, esta...           11  other
# 5909    [un, porque, de, otra, el, estuvo, pero, la, f...           14  other
# ...                                                   ...          ...    ...
# 212251  [un, de, dans, la, de, qui, une, à, proximité,...           35  other
# 212616                                             [j, j]            2  other
# 212654  [c, est, un, du, de, montréal, qui, guidé, le,...          159  other
# 213240  [un, de, mes, je, de, pour, y, aller, était, à...           14  other
# 213623                       [los, y, una, la, como, las]            6  other
# 213844  [décadent, réconfortante, pas, et, décontracté...           13  other
# 214327  [les, sont, délicieuses, mais, le, végé, est, ...           16  other
# 215331  [il, y, que, je, l, j, ai, eu, un, été, et, j,...           74  other
# 215353  [un, de, y, era, era, y, sin, nada, que, lásti...           18  other
# 215390  [qui, y, aller, ses, sur, y, des, du, et, et, ...           42  other
# 215483  [kann, nur, aus, sie, nicht, das, anderer, daf...           17  other
# 215948  [好耐无吃subway, 突然想吃, 呢间subway虽然系超市隔离, 但不算特别人多, 通...           10  other
# 216127  [suis, hier, à, génial, de, la, de, qualité, e...           11  other
# 216268  [déjeuners, pour, un, très, de, la, est, très,...           22  other
# 216309  [un, déçu, de, ce, en, je, que, l, pour, ce, q...           12  other
# 216379  [每次经过总有一堆人排队, 晚上去问左门口排筹个人几点关门, 晚上唔晒就排下, 比早上排得快...           21  other
# 216702  [il, y, un, à, côté, du, métro, sur, la, à, la...           61  other
# 216797  [ist, denn, jetzt, los, wo, mir, vor, noch, ei...           82  other
# 216886  [très, pour, un, pour, une, du, j, ai, eu, la,...           14  other
# 217074  [que, le, de, par, un, là, vous, vous, un, que...           29  other
# 217075  [le, est, un, qui, du, est, pensé, du, au, déc...           16  other
# 217365  [le, du, un, décor, différent, de, la, des, en...           57  other
# 217833  [el, fue, muy, y, al, el, baño, de, las, de, l...           25  other
# 217978  [organisés, des, crèmes, glacées, à, et, des, ...           13  other
# 218066  [l, est, mais, chère, il, à, mais, à, une, de,...           24  other
# 218095  [muy, con, otros, la, muy, y, decoración, la, ...           12  other
# 218821  [à, récemment, généreuses, variétés, la, flamb...           15  other
# 219057  [la, clientèle, très, médiocre, que, nous, y, ...           25  other
# 219087  [mi, para, que, fuera, el, de, y, con, y, y, y...           56  other
# 219802  [la, pâte, est, et, différente, je, c, est, un...           17  other
#
# [843 rows x 14 columns]

# %%
not_eng.shape
# Out:
# (843, 14)

# %%
maybe_eng[maybe_eng.lang == '?']
# Out:
# Empty DataFrame
# Columns: [business_id, city, date, name, review_id, stars, state, text, useful, word_count, text_tok, not_eng, num_non_eng, lang]
# Index: []

# %%
tempDF = tempDF.drop(not_eng.index)

# %%
tempDF.shape
# Out:
# (219664, 13)

# %%
fastFood_eng = tempDF

# %%
#fastFood_eng = spark.createDataFrame(tempDF)

# %% [markdown]
# ## Make X and y

# %%
def make_xy(reviewDF, vectorizer=None, min_df = 1, max_df = 1.0):
    if vectorizer is None:
        print('The value of vectorizer is None ... using CountVectorizer')
    else:
        print('The value of vectorizer is NOT None ... using the provided vectorizer')
    #
    if vectorizer is None:
        vectorizer = CountVectorizer(strip_accents = 'ascii', stop_words = sw, 
                                     min_df = min_df, max_df = max_df)
    X = vectorizer.fit_transform(reviewDF.text_tok)
    X = X.tocsc() 
    y = reviewDF.stars
    return X, y, vectorizer

# %%
X, y, vectorizer = make_xy(fastFood_eng)
# Out:
# The value of vectorizer is None ... using CountVectorizer

# %%
n_rows, n_cols = X.shape
print('Number of reviews: ', n_rows)
print('Number of terms: ', n_cols)
# Out:
# Number of reviews:  219664
# Number of terms:  72084

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=123)

nb = MultinomialNB()
nb.fit(Xtrain, ytrain)
train_accuracy = nb.score(Xtrain, ytrain)
test_accuracy = nb.score(Xtest, ytest)

print("[Training Classification Report:]")
print(classification_report(ytrain, nb.predict(Xtrain)))
print('Training Accuracy: ',train_accuracy)
print('')
print("[Test Classification Report:]")
print(classification_report(ytest, nb.predict(Xtest)))
print('Test Accuracy: ', test_accuracy)
# Out:
# [Training Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.72      0.84      0.78     42004
#          2.0       0.47      0.32      0.38     18620
#          3.0       0.54      0.43      0.48     21441
#          4.0       0.56      0.55      0.55     34079
#          5.0       0.73      0.79      0.76     48604
#
#    micro avg       0.65      0.65      0.65    164748
#    macro avg       0.60      0.59      0.59    164748
# weighted avg       0.64      0.65      0.64    164748
#
# Training Accuracy:  0.6528819773229417
#
# [Test Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.70      0.82      0.76     13981
#          2.0       0.34      0.23      0.28      6207
#          3.0       0.40      0.32      0.35      7093
#          4.0       0.48      0.48      0.48     11552
#          5.0       0.70      0.75      0.72     16083
#
#    micro avg       0.60      0.60      0.60     54916
#    macro avg       0.52      0.52      0.52     54916
# weighted avg       0.57      0.60      0.58     54916
#
# Test Accuracy:  0.5950724743244228

# %% [markdown]
# We see there is overfitting from the gap in training accuracy and testing accuracy.  We will use CDFs of the document frequency to choose the hyperparameters.

# %%
feature_names = vectorizer.get_feature_names()

# %%
word_frequencies = np.array([X[:,i].count_nonzero() for i in range(n_cols)])

# %%
len(word_frequencies[word_frequencies==1])
# Out:
# 32753

# %%
max_doc_freq = np.max(word_frequencies)
x_values = range(max_doc_freq)
x_values
# Out:
# range(0, 97991)

# %%
#what word appears in the most reviews?
most_freq_idx = list(word_frequencies).index(max_doc_freq)
feature_names[most_freq_idx]
# Out:
# 'food'

# %% [markdown]
# It makes sense that "food" is the word that appears in the most fast food reviews (after removing stop words).

# %% [markdown]
# ## Hyperparameter Tuning

# %%
y_values  = np.array([np.sum(word_frequencies <= i) for i in x_values])/n_cols

plt.figure(figsize=(12,12))
plt.plot(x_values,y_values, marker = 'o',markersize = 2, linestyle = 'none')

plt.xlabel('Document Frequencies')
plt.ylabel('% of Terms that Appear in x or Fewer Docs')
plt.title('CDF of Document Frequencies')
plt.savefig('../SavedFiles/CDFofDocFreq')

# %%
plt.plot(x_values,y_values, marker = 'o',linestyle = 'none')
plt.xlim([-1,50])
plt.xlabel('Document Frequencies')
plt.ylabel('% of Terms that Appear in x or Fewer Docs')
plt.title('Zoomed CDF of Document Frequencies')
plt.savefig('../SavedFiles/ZoomedCDFofDocFreq')

# %%
plt.plot(x_values,y_values, marker = '.', markersize = 0.02,linestyle = 'none')
plt.xlim(50000,98000)
plt.ylim(0.99,1.001)
plt.xlabel('Document Frequencies')
plt.ylabel('% of Terms that Appear in x or Fewer Docs')
plt.title('Zoomed CDF of Document Frequencies')
# Out:
# Text(0.5, 1.0, 'Zoomed CDF of Document Frequencies')

# %%
X, y, vectorizer = make_xy(fastFood_eng, min_df = 3, max_df = 70000)
# Out:
# The value of vectorizer is None ... using CountVectorizer

# %%
n_rows, n_cols = X.shape
print('Number of reviews: ', n_rows)
print('Number of terms: ', n_cols)
# Out:
# Number of reviews:  219664
# Number of terms:  31107

# %%
feature_names = vectorizer.get_feature_names()
word_frequencies = np.array([X[:,i].count_nonzero() for i in range(n_cols)])
max_doc_freq = np.max(word_frequencies)
x_values = range(max_doc_freq)
x_values
# Out:
# range(0, 69132)

# %%
most_freq_idx = list(word_frequencies).index(max_doc_freq)
feature_names[most_freq_idx]
# Out:
# 'good'

# %% [markdown]
# ## Naive Bayes

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, random_state=123)

nb = MultinomialNB()
nb.fit(Xtrain, ytrain)
ypred = nb.predict(Xtest)

print("[Training Classification Report:]")
print(classification_report(ytrain, nb.predict(Xtrain)))
print('Training Accuracy: ',accuracy_score(nb.predict(Xtrain), ytrain))
print('')
print("[Test Classification Report:]")
print(classification_report(ytest, ypred))
print('Test Accuracy: ', accuracy_score(ypred, ytest))
# Out:
# [Training Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.73      0.82      0.77     42004
#          2.0       0.42      0.35      0.38     18620
#          3.0       0.50      0.44      0.47     21441
#          4.0       0.55      0.52      0.54     34079
#          5.0       0.73      0.78      0.75     48604
#
#    micro avg       0.64      0.64      0.64    164748
#    macro avg       0.59      0.58      0.58    164748
# weighted avg       0.63      0.64      0.63    164748
#
# Training Accuracy:  0.6413188627479545
#
# [Test Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.72      0.80      0.76     13981
#          2.0       0.34      0.27      0.30      6207
#          3.0       0.40      0.35      0.37      7093
#          4.0       0.48      0.46      0.47     11552
#          5.0       0.70      0.74      0.72     16083
#
#    micro avg       0.59      0.59      0.59     54916
#    macro avg       0.53      0.53      0.53     54916
# weighted avg       0.58      0.59      0.59     54916
#
# Test Accuracy:  0.5944169276713526

# %% [markdown]
# There is slightly less overfitting, but the test accuracy is also slightly worse.

# %%
confusion_matrix(ytest, ypred)
# Out:
# array([[11219,  1810,   566,   206,   180],
#        [ 2353,  1706,  1473,   463,   212],
#        [  914,   904,  2502,  2049,   724],
#        [  540,   413,  1375,  5316,  3908],
#        [  610,   220,   382,  2971, 11900]])

# %% [markdown]
# ## Logistic Regression

# %%
#Cross VALIDATION
param_grid = {'C': [0.001, 0.1, 1, 10, 100]}
logistic = LogisticRegression(solver = 'lbfgs', multi_class = 'auto')
logreg_cv = GridSearchCV(logistic, param_grid, cv = 5)
fitted = logreg_cv.fit(Xtrain, ytrain)
print("Tuned Logistic Regression Parameters: {}".format(logreg_cv.best_params_)) 
print("Best score is {}".format(logreg_cv.best_score_))
# Out:
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Tuned Logistic Regression Parameters: {'C': 0.1}
# Best score is 0.6246327724767524
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
ypred = fitted.predict(Xtest)

print("[Training Classification Report:]")
print(classification_report(ytrain, fitted.predict(Xtrain)))
print('Training Accuracy: ',accuracy_score(fitted.predict(Xtrain), ytrain))
print('')
print("[Test Classification Report:]")
print(classification_report(ytest, ypred))
print('Test Accuracy: ', accuracy_score(ypred, ytest))
# Out:
# [Training Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.77      0.91      0.84     42004
#          2.0       0.61      0.38      0.47     18620
#          3.0       0.60      0.46      0.52     21441
#          4.0       0.60      0.52      0.56     34079
#          5.0       0.72      0.85      0.78     48604
#
#    micro avg       0.69      0.69      0.69    164748
#    macro avg       0.66      0.62      0.63    164748
# weighted avg       0.68      0.69      0.68    164748
#
# Training Accuracy:  0.6946184475684075
#
# [Test Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.75      0.88      0.81     13981
#          2.0       0.43      0.27      0.33      6207
#          3.0       0.44      0.35      0.39      7093
#          4.0       0.51      0.43      0.46     11552
#          5.0       0.68      0.82      0.74     16083
#
#    micro avg       0.63      0.63      0.63     54916
#    macro avg       0.56      0.55      0.55     54916
# weighted avg       0.60      0.63      0.61     54916
#
# Test Accuracy:  0.627831597348678

# %%
confusion_matrix(ytest, ypred)
# Out:
# array([[12307,   949,   292,   143,   290],
#        [ 2736,  1660,  1114,   366,   331],
#        [  869,   945,  2479,  1895,   905],
#        [  345,   219,  1365,  4914,  4709],
#        [  260,   100,   333,  2272, 13118]])

# %% [markdown]
# We see from the above confusion matrix that the model is clearly better at classifying the 1-star and 5-star reviews, with 12,307 and 13,118 correctly classified respectively.

# %%
#try to balance classes

#Cross VALIDATION
param_grid = {'C': [0.001, 0.1, 1, 10, 100]}
logistic = LogisticRegression(solver = 'lbfgs', class_weight = 'balanced', multi_class = 'auto')
logreg_cv = GridSearchCV(logistic, param_grid, cv = 5)
fitted = logreg_cv.fit(Xtrain, ytrain)
print("Tuned Logistic Regression Parameters: {}".format(logreg_cv.best_params_)) 
print("Best score is {}".format(logreg_cv.best_score_))
# Out:
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Tuned Logistic Regression Parameters: {'C': 0.1}
# Best score is 0.6083837133075971
# /Users/sineadoconnor/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
ypred = fitted.predict(Xtest)

print("[Training Classification Report:]")
print(classification_report(ytrain, fitted.predict(Xtrain)))
print('Training Accuracy: ',accuracy_score(fitted.predict(Xtrain), ytrain))
print('')
print("[Test Classification Report:]")
print(classification_report(ytest, ypred))
print('Test Accuracy: ', accuracy_score(ypred, ytest))
# Out:
# [Training Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.85      0.80      0.83     42004
#          2.0       0.50      0.62      0.55     18620
#          3.0       0.54      0.58      0.56     21441
#          4.0       0.60      0.54      0.57     34079
#          5.0       0.77      0.77      0.77     48604
#
#    micro avg       0.69      0.69      0.69    164748
#    macro avg       0.65      0.66      0.66    164748
# weighted avg       0.70      0.69      0.69    164748
#
# Training Accuracy:  0.688560710903926
#
# [Test Classification Report:]
#               precision    recall  f1-score   support
#
#          1.0       0.81      0.76      0.78     13981
#          2.0       0.36      0.44      0.40      6207
#          3.0       0.39      0.43      0.41      7093
#          4.0       0.50      0.44      0.47     11552
#          5.0       0.73      0.73      0.73     16083
#
#    micro avg       0.61      0.61      0.61     54916
#    macro avg       0.56      0.56      0.56     54916
# weighted avg       0.62      0.61      0.61     54916
#
# Test Accuracy:  0.606999781484449

# %%
#pickle the fast food data frame of English reviews for use in further sections
outfile = open('../SavedFiles/fastFood_eng.pkl', 'wb')
pickle.dump(fastFood_eng, outfile)
outfile.close()
